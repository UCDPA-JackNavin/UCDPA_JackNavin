# %%
import pandas as pd

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("EPL_20_21.csv")

# %%
data
# Out:
#                   Name              Club Nationality Position  Age  Matches  \
# 0          Mason Mount           Chelsea         ENG    MF,FW   21       36
# 1        Edouard Mendy           Chelsea         SEN       GK   28       31
# 2          Timo Werner           Chelsea         GER       FW   24       35
# 3         Ben Chilwell           Chelsea         ENG       DF   23       27
# 4          Reece James           Chelsea         ENG       DF   20       32
# ..                 ...               ...         ...      ...  ...      ...
# 527        Lys Mousset  Sheffield United         FRA    FW,MF   24       11
# 528     Jack O'Connell  Sheffield United         ENG       DF   26        2
# 529      Iliman Ndiaye  Sheffield United         FRA       MF   21        1
# 530  Antwoine Hackford  Sheffield United         ENG    DF,FW   16        1
# 531        Femi Seriki  Sheffield United         ENG       DF   17        1
#
# ...

# %%
v = ['Goals','Assists','Penalty_Goals','Red_Cards']
for colname in v:
    x = x=pd.DataFrame(data.groupby(['Club'])[colname].sum().reset_index(drop=False).sort_values(by=colname,ascending=True).reset_index(drop=True))
    display(x.style.background_gradient( cmap='terrain'))
    sns.set(rc={'figure.figsize':(20,7.5)})
    sns.barplot(x='Club',y=colname,data=x,palette="terrain")
    plt.title('The most {} in the EPL 2020 - 2021'.format(colname),fontsize=18)
    plt.xlabel(' ')
    plt.ylabel('count of {}'.format(colname),fontsize=16)
    plt.xlabel(' ')
    plt.xticks(ticks=np.arange(0,20,1),labels=x['Club'],fontsize=16,style='italic',rotation=90)
    plt.yticks(fontsize=16)
    plt.show()
# Out:
# <style type="text/css">
# #T_1b61a_row0_col1 {
#   background-color: #333399;
#   color: #f1f1f1;
# }
# #T_1b61a_row1_col1 {
#   background-color: #0e7ee4;
#   color: #f1f1f1;
# }
# #T_1b61a_row2_col1 {
#   background-color: #00b4ac;
#   color: #f1f1f1;
# }
# #T_1b61a_row3_col1 {
#   background-color: #00bc94;
#   color: #f1f1f1;
# }
# #T_1b61a_row4_col1 {
#   background-color: #00c47d;
#   color: #000000;
# }
# #T_1b61a_row5_col1, #T_1b61a_row6_col1 {
#   background-color: #45da74;
#   color: #000000;
# }
# #T_1b61a_row7_col1 {
#   background-color: #95ea84;
#   color: #000000;
# }
# #T_1b61a_row8_col1 {
#   background-color: #a5ed87;
#   color: #000000;
# }
# #T_1b61a_row9_col1 {
#   background-color: #c5f38d;
#   color: #000000;
# }
# #T_1b61a_row10_col1 {
#   background-color: #f2ee92;
#   color: #000000;
# }
# #T_1b61a_row11_col1 {
#   background-color: #eae48e;
#   color: #000000;
# }
# #T_1b61a_row12_col1 {
#   background-color: #d2c581;
#   color: #000000;
# }
# ...
